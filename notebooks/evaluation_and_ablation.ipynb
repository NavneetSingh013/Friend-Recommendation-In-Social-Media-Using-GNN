# %% [markdown]
# # Evaluation and Ablation Study
#
# This notebook provides comprehensive evaluation and ablation study for all models.
#
# ## Evaluation:
# 1. Compare all models (GraphSAGE, GAT, SEAL, Baselines)
# 2. Metrics: AUC, AP, Precision@K, Recall@K, NDCG@K, MAP@K
# 3. Ablation study: hyperparameters, model variants
# 4. Runtime and memory profiling

# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd())))

import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from src.evaluation import compute_metrics, compute_ranking_metrics
import time

# Load data
data = torch.load("data/processed/facebook_combined.pt")
link_data = torch.load("data/processed/facebook_link_data.pt")

test_edges = link_data['test_edges']
test_labels = link_data['test_labels'].numpy()

print("Data loaded. Ready for evaluation.")
